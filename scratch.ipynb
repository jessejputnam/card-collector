# %% [markdown]
# # PLAN
# - Manually update sets with id, i.e. 'swsh3' if null
#     - setId will be
# - manually update set logo if null
# - mamnually update card tcgPlayerId if null
#     - Will require setId on sets first
#     - Will also require checks against cardNumber with potential split on "/" and removing leading 0's

# %% [markdown]
#     63530df07ee6ec5a7932dd28
#
#     {
#       id: '68af8734c4f780b5153e9578',
#       tcgPlayerId: '232380',
#       setId: '68af47c1190c4823de2527c1',
#       setName: 'Shining Fates',
#       name: 'Dhelmise VMAX',
#       cardNumber: '010/072',
#       totalSetNumber: '072',
#       rarity: 'Ultra Rare',
#       cardType: 'Grass',
#       hp: 330,
#       stage: 'VMAX',
#       attacks: [Array],
#       weakness: [Object],
#       resistance: [Object],
#       retreatCost: 3,
#       artist: null,
#       tcgPlayerUrl: 'https://www.tcgplayer.com/product/232380/pokemon-shining-fates-dhelmise-vmax',
#       prices: [Object],
#       imageCdnUrl: 'https://tcgplayer-cdn.tcgplayer.com/product/232380_in_800x800.jpg',
#       imageCdnUrl200: 'https://tcgplayer-cdn.tcgplayer.com/product/232380_in_200x200.jpg',
#       imageCdnUrl400: 'https://tcgplayer-cdn.tcgplayer.com/product/232380_in_400x400.jpg',
#       imageCdnUrl800: 'https://tcgplayer-cdn.tcgplayer.com/product/232380_in_800x800.jpg',
#       imageUrl: 'https://tcgplayer-cdn.tcgplayer.com/product/232380_in_200x200.jpg',
#       needsDetailedScrape: false,
#       dataCompleteness: 100,
#       lastScrapedAt: '2025-12-05T22:42:17.391Z',
#       createdAt: '2025-08-27T22:31:16.705Z',
#       updatedAt: '2025-12-05T22:42:17.541Z'
#     }

# %% [markdown]
# 63530d127ee6ec5a7932dce2

# %% [markdown]
# - " not available"
# - holofoil
# - normal
# - unlimitedHolofoil
# - unlimited
# - 1stEdition
# - 1stEditionHolofoil
# - reverseHolofoil
#
# !card.tcgplayer ? " not available" : !prices ? "  not available" : prices.holofoil && prices.holofoil.market ? prices.holofoil.market.toFixed(2) : prices.holofoil && prices.holofoil.mid ? prices.holofoil.mid.toFixed(2) : prices.normal && prices.normal.market ? prices.normal.market.toFixed(2) : prices.normal && prices.normal.mid ? prices.normal.mid.toFixed(2) : prices.unlimitedHolofoil ? prices.unlimitedHolofoil.market.toFixed(2) : prices.unlimited ? prices.unlimited.market.toFixed(2) : prices["1stEdition"] ? prices["1stEdition"].market.toFixed(2) : prices["1stEditionHolofoil"] ? prices["1stEditionHolofoil"].market.toFixed(2) : prices.reverseHolofoil ?  card.tcgplayer.prices.reverseHolofoil.mid.toFixed(2) : "No price available"}
